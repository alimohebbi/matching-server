# %%
import pandas as pd
t = pd.read_csv('thresholds.csv')

# %%
t.groupby(['train_set','embedding', 'algorithm'])['threshold'].describe().to_csv('info.csv')

# %%
t
# Out:
#      train_set embedding   algorithm  threshold       f-1  \
# 0      android      fast         atm       0.67  0.117647
# 1      android      fast  craftdroid       0.69  0.153846
# 2      android      fast      custom       0.77  0.166667
# 3      android     glove         atm       0.58  0.142857
# 4      android     glove  craftdroid       0.50  0.153846
# ...        ...       ...         ...        ...       ...
# 2767  standard       w2v  craftdroid       0.28  0.142857
# 2768  standard       w2v      custom       0.41  0.166667
# 2769  standard        wm         atm       0.22  0.142857
# 2770  standard        wm  craftdroid       0.20  0.133333
# 2771  standard        wm      custom       0.25  0.153846
#
#                             app_pairs
# 0     ExpenseTracker1-ExpenseTracker2
# 1     ExpenseTracker1-ExpenseTracker2
# 2     ExpenseTracker1-ExpenseTracker2
# 3     ExpenseTracker1-ExpenseTracker2
# 4     ExpenseTracker1-ExpenseTracker2
# ...
